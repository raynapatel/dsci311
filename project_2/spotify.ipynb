# %% [markdown]
# #### Spotify Trends ###
#
# Investigating the growth of female vs. male artists from 2010 to 2023. Also investigating the growth by gender throughout different genres and overall. Hoping to use this algorithm to "predict" what combination of stylistic elements can be combined to create a popular song at each time.

# %%
import pandas as pd
import seaborn as sns
import csv
import numpy as np
import matplotlib.pyplot as plt
import zipfile
from pathlib import Path

# %%
artist_info = pd.read_csv("artist_metadata.csv")
artist_info
# Out:
#       Unnamed: 0  index              artist  gender  age    type country  \
# 0              0      0               Drake    male   33  person      CA
# 1              1      1         Post Malone    male   25  person      US
# 2              2      2          Ed Sheeran    male   29  person      GB
# 3              3      3            J Balvin    male   35  person      CO
# 4              4      4           Bad Bunny    male   26  person      PR
# ...          ...    ...                 ...     ...  ...     ...     ...
# 9995        9995   4991          si_el_bien     NaN    0     NaN     NaN
# 9996        9996   4992  Antonello Venditti    male   71  person      IT
# 9997        9997   4993         Lea Salonga  female   49  person      PH
# 9998        9998   4994    Vertical Horizon   mixed   29   group     NaN
# 9999        9999   4995               Lakko    male    0  person      ES
#
#        city_1 district_1    city_2 district_2 city_3 district_3
# ...

# %%
tracks = pd.read_csv("playlist_data.csv", encoding="latin1")
tracks
# Out:
#                                            playlist_url  year  \
# 0     https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1     https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2     https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3     https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4     https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# ...                                                 ...   ...
# 2395  https://open.spotify.com/playlist/6unJBM7ZGitZ...  2023
# 2396  https://open.spotify.com/playlist/6unJBM7ZGitZ...  2023
# 2397  https://open.spotify.com/playlist/6unJBM7ZGitZ...  2023
# 2398  https://open.spotify.com/playlist/6unJBM7ZGitZ...  2023
# 2399  https://open.spotify.com/playlist/6unJBM7ZGitZ...  2023
#
#                     track_id              track_name  track_popularity  \
# 0     6naxalmIoLFWR0siv8dnQQ  Oops!...I Did It Again                81
# 1     2m1hi0nfMR9vdGC8UcrnwU    All The Small Things                83
# ...

# %%
tracks.columns
# Out:
# Index(['playlist_url', 'year', 'track_id', 'track_name', 'track_popularity',
#        'album', 'artist_id', 'artist_name', 'artist_genres',
#        'artist_popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')
